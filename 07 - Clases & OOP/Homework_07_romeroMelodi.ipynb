# %% [markdown]
# # Solución Ejercicio 07 POO

# %%
""" 1) Crear la clase vehículo que contenga los atributos:<br>
Color<br>
Si es moto, auto, camioneta ó camión<br>
Cilindrada del motor
""" 

class vehiculo:
    def __init__(self, color, tipo, cilindrada):
        self.color  = color
        self.tipo   = tipo
        self.cilindrada = cilindrada

# %%
""" 2) A la clase Vehiculo creada en el punto 1, agregar los siguientes métodos:<br>
Acelerar<br>
Frenar<br>
Doblar<br>
"""
class vehiculo:
    def __init__(self, color, tipo, cilindrada):
        self.color  = color
        self.tipo   = tipo
        self.cilindrada = cilindrada

    def acelerar(self):
        print('soy un '+ self.tipo + ' acelerando')

    def frenar(self):
        print('soy un '+ self.tipo + ' frenando')

    def doblar(self):
        print('soy un '+ self.tipo +  ' doblando')

# %%
""" 3) Instanciar 3 objetos de la clase vehículo y ejecutar sus métodos,
 probar luego el resultado
""" 
corola = vehiculo('rojo', 'auto', 1.6)
corola.acelerar()
motomel = vehiculo('negro', 'moto', 110)
motomel.frenar()
camioneta = vehiculo('rojo', 'camioneta', 2.7)
camioneta.doblar()
# Out:
# soy un autoacelerando
# soy un motofrenando
# soy un camionetadoblando

# %%
""" 4) Agregar a la clase Vehiculo, un método que muestre su estado, es decir, 
a que velocidad se encuentra y su dirección. Y otro método que muestre color, 
tipo y cilindrada """ 
class vehiculo:
    def __init__(self, color, tipo, cilindrada):
        self.color  = color
        self.tipo   = tipo
        self.cilindrada = cilindrada
        self.velocidad = 0
        self.direccion = 0

    def acelerar(self, velocidad):
        self.velocidad += velocidad

    def frenar(self, velocidad):
        self.velocidad -= velocidad

    def doblar(self, direccion):
        self.direccion = direccion

    def estado(self):
        print(f'soy un {self.tipo} a {self.velocidad} en una dirección de {self.direccion}')

    def presentar(self):
        print(f'soy un {self.tipo}  de {self.cilindrada} cilindradas, color: {self.color}')
        
miauto = vehiculo('verde', 'auto', 1.6)
miauto.acelerar(3)
miauto.doblar(80)
miauto.estado()
# Out:
# soy un auto a 3 en una dirección de 80

# %%
""" 5) Crear una clase que permita utilizar las funciones creadas en la práctica del módulo 6<br>
Verificar Primo<br>
Valor modal<br>
Conversión grados<br>
Factorial<br>
"""

class modulo06:
    def __init__(self) -> None:
        pass

    def esPrimo(self, x):
        primo = True
        for i in range(2,x):
            if (x % i == 0):
                primo = False
            
        return primo

    def devolverPrimos(self, milista):
        primos = []

        for e,i in enumerate(milista):
            if (self.esPrimo(i) == True):
                primos.append(i)
        
        return primos
    
    def devolverRepetido(self, milista, tipo = 1):
        """ 
        Funcionq ue devuelve el menor o mayor nro repetido en un array de numeros.
        Listado: es el array de nros. 
        Tipo: vale 1 o 2, 1 indica que devuelve el menor nro repetido
        y 2 devuelve el mayor numero repetido.- 
        """ 

        repetido = 0
        veces   = 0

        for i in milista:
            if (milista.count(i) >= veces):
                if (milista.count(i) == veces):
                    if (tipo == 1 and i < repetido):
                        repetido = i
                        break
                    elif(tipo == 2 and i > repetido):
                        repetido = i
                        break
                else: 
                    repetido = i
                    veces = milista.count(i)
        
        return repetido

        
    def resolverGrados(self, valor, origen, destino):
        """ Función que convierta entre grados Celsius, Farenheit y Kelvin. 
            Debe recibir 3 parámetros: el valor, la medida de orígen y la medida de destino
            origen y destino pueden valer 'F', 'C' o 'K'
        """ 
        resultado = 0
        if (destino != 'F' or destino !='C' or destino != 'K'):
            if not(origen != 'F' or origen !='C' or origen != 'K'):
                print('El parametro del origen es inválido.')
                return 0
            
            if (origen == 'F'):

                if (destino == 'F'):
                    return valor
                elif(destino == 'C'):
                    return (valor - 32) * 5 / 9
                else: # entonces destino = 'K'
                    return ((valor - 32) * 5 / 9) + 273.15

            elif(origen == 'C'):
                if (destino == 'C'):
                    return valor
                elif(destino == 'F'):
                    return (valor * 9 / 5) + 32 
                else: # entonces destino = 'K'
                    return valor + 273.15

            else: #entocnes origen = 'K'

                if (destino == 'K'):
                    return valor
                elif(destino == 'F'):
                    return ((valor - 273.15) * 9 / 5) + 32 
                else: # entonces destino = 'C'
                    return (valor - 273.15)
        else:
            print('El parametro del destino es inválido.')
            return 0

        
    def factorial(self, n):

        if (n < 1 or type(n) != int):
            return("No se acepta un número no entero o negativo ")
            
        if (n == 1):
            return 1
        else:
            return n * self.factorial(n-1)

# %%
# 6) Probar las funciones incorporadas en la clase del punto 5
f = modulo06()

print(f.factorial(5))

print(f.esPrimo(3))

print(f.resolverGrados(1,'F','C'))
# Out:
# 120
# True
# -17.22222222222222

# %%
""" 7) Es necesario que la clase creada en el punto 5 contenga una lista, 
sobre la cual se aplquen las funciones incorporadas """ 

class modulo06:
    def __init__(self, lista):
        self.lista = lista

    def esPrimo(self, x):
        primo = True
        for i in range(2,x):
            if (x % i == 0):
                primo = False
            
        return primo

    def devolverPrimos(self):
        primos = []

        for e,i in enumerate(self.lista):
            if (self.esPrimo(i) == True):
                primos.append(i)
        
        return primos
    
    def devolverRepetido(self, tipo = 1):
        """ 
        Funcion que devuelve el menor o mayor nro repetido en un array de numeros.
        Listado: es el array de nros. 
        Tipo: vale 1 o 2, 1 indica que devuelve el menor nro repetido
        y 2 devuelve el mayor numero repetido.- 
        """ 

        repetido = 0
        veces   = 0

        for i in self.lista:
            if (self.lista.count(i) >= veces):
                if (self.lista.count(i) == veces):
                    if (tipo == 1 and i < repetido):
                        repetido = i
                        break
                    elif(tipo == 2 and i > repetido):
                        repetido = i
                        break
                else: 
                    repetido = i
                    veces = self.lista.count(i)
        
        return repetido

        
    def resolverGrados(self, valor, origen, destino):
        """ Función que convierta entre grados Celsius, Farenheit y Kelvin. 
            Debe recibir 3 parámetros: el valor, la medida de orígen y la medida de destino
            origen y destino pueden valer 'F', 'C' o 'K'
        """ 
        resultado = 0
        if (destino != 'F' or destino !='C' or destino != 'K'):
            if not(origen != 'F' or origen !='C' or origen != 'K'):
                print('El parametro del origen es inválido.')
                return 0
            
            if (origen == 'F'):

                if (destino == 'F'):
                    return valor
                elif(destino == 'C'):
                    return (valor - 32) * 5 / 9
                else: # entonces destino = 'K'
                    return ((valor - 32) * 5 / 9) + 273.15

            elif(origen == 'C'):
                if (destino == 'C'):
                    return valor
                elif(destino == 'F'):
                    return (valor * 9 / 5) + 32 
                else: # entonces destino = 'K'
                    return valor + 273.15

            else: #entocnes origen = 'K'

                if (destino == 'K'):
                    return valor
                elif(destino == 'F'):
                    return ((valor - 273.15) * 9 / 5) + 32 
                else: # entonces destino = 'C'
                    return (valor - 273.15)
        else:
            print('El parametro del destino es inválido.')
            return 0

        
    def factorial(self, n):

        if (n < 1 or type(n) != int):
            return("No se acepta un número no entero o negativo ")
            
        if (n == 1):
            return 1
        else:
            return n * self.factorial(n-1)


    def devolverFactorial(self):

        for elemento in self.lista:
            print(self.factorial(elemento))

# %%
""" 8) Crear un archivo .py aparte y ubicar allí la clase generada en el punto anterior. 
Luego realizar la importación del módulo y probar alguna de sus funciones """
import sys

sys.path.append(r'c:/xampp/htdocs/CarpetaHenry Python-Prep - Data Science/07 - Clases & OOP/modulo7.py')

print(dir())

import modulo7 as m

a = m.modulo_7([1,2,5,8,8,9,2])

print(a.esPrimo(8))
# Out:
# ['In', 'Out', '_', '_10', '_11', '_14', '_16', '_17', '_41', '_42', '_5', '_6', '_7', '_9', '__', '___', '__annotations__', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '__vsc_ipynb_file__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i31', '_i32', '_i33', '_i34', '_i35', '_i36', '_i37', '_i38', '_i39', '_i4', '_i40', '_i41', '_i42', '_i43', '_i44', '_i45', '_i46', '_i47', '_i48', '_i49', '_i5', '_i50', '_i51', '_i52', '_i53', '_i54', '_i55', '_i56', '_i57', '_i58', '_i59', '_i6', '_i60', '_i61', '_i62', '_i63', '_i64', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'camioneta', 'corola', 'exit', 'f', 'get_ipython', 'm', 'miauto', 'modulo06', 'modulo7', 'motomel', 'os', 'quit', 'sys', 'vehiculo']
# ---------------------------------------------------------------------------
# ...

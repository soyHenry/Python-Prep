# %%
def dividir(num1, num2):
    try:
        resultado = num1 / num2
        return resultado
    except ZeroDivisionError:
        print("No se puede dividir por cero.")
        return None

# %%
dividir(12, 0)
# Out:
# No se puede dividir por cero.

# %%
try:
    with open("archivo.txt", "r") as f:
        contenido = f.read()
except FileNotFoundError:
    print("El archivo no existe.")
# Out:
# El archivo no existe.

# %%
def primera_letra(lista_de_palabras):
  primeras_letras = []

  for palabra in lista_de_palabras:
    assert type(palabra) == str, f'{palabra} no es str'
    assert len(palabra) > 0, 'No se permiten str vacíos'

    primeras_letras.append(palabra[0])
  return primeras_letras

# %%
primera_letra(["Hola", "Mundo", 42])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 primera_letra(["Hola", "Mundo", 42])
#
# Cell In[4], line 5, in primera_letra(lista_de_palabras)
#       2 primeras_letras = []
#       4 for palabra in lista_de_palabras:
# ----> 5   assert type(palabra) == str, f'{palabra} no es str'
#       6   assert len(palabra) > 0, 'No se permiten str vacíos'
#       8   primeras_letras.append(palabra[0])
#
# AssertionError: 42 no es str
